# %% [markdown]
# ## Surface plot and  Data visualisation

# %%
# mpl_toolkits.mplot3d provides some basic 3D plotting (scatter, surf, line, mesh) tools. 
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
a = np.array([1,2,3])
b = np.array([4,5,6,7])

# Return coordinate matrices from coordinate vectors.
# Make N-D coordinate arrays for vectorized evaluations of N-D scalar/vector 
# fields over N-D grids, given one-dimensional coordinate arrays x1, x2,…, xn.

# creating a surface matrix
a,b = np.meshgrid(a,b)

print(a)
print(b)
# Out:
# [[1 2 3]
#  [1 2 3]
#  [1 2 3]
#  [1 2 3]]
# [[4 4 4]
#  [5 5 5]
#  [6 6 6]
#  [7 7 7]]

# %%
# creating a 3d space
# Figure, which contains all the plot elements.
fig = plt.figure()
# The gca() method figure module of matplotlib library is used to get the current axes.
axes = fig.gca(projection="3d")
plt.show()

# %%
# creating a 3d space
# Figure, which contains all the plot elements.
fig = plt.figure()
# The gca() method figure module of matplotlib library is used to get the current axes.
axes = fig.gca(projection="3d")
axes.plot_surface(a,b,a+b,cmap="coolwarm")
plt.show()

# %%
a = np.arange(-1,1,0.02)
b = a

# Return coordinate matrices from coordinate vectors.
# Make N-D coordinate arrays for vectorized evaluations of N-D scalar/vector 
# fields over N-D grids, given one-dimensional coordinate arrays x1, x2,…, xn.

# creating a surface matrix
a,b = np.meshgrid(a,b)

print(a)
print(b)
# Out:
# [[-1.   -0.98 -0.96 ...  0.94  0.96  0.98]
#  [-1.   -0.98 -0.96 ...  0.94  0.96  0.98]
#  [-1.   -0.98 -0.96 ...  0.94  0.96  0.98]
#  ...
#  [-1.   -0.98 -0.96 ...  0.94  0.96  0.98]
#  [-1.   -0.98 -0.96 ...  0.94  0.96  0.98]
#  [-1.   -0.98 -0.96 ...  0.94  0.96  0.98]]
# [[-1.   -1.   -1.   ... -1.   -1.   -1.  ]
#  [-0.98 -0.98 -0.98 ... -0.98 -0.98 -0.98]
#  [-0.96 -0.96 -0.96 ... -0.96 -0.96 -0.96]
#  ...
#  [ 0.94  0.94  0.94 ...  0.94  0.94  0.94]
#  [ 0.96  0.96  0.96 ...  0.96  0.96  0.96]
#  [ 0.98  0.98  0.98 ...  0.98  0.98  0.98]]

# %% [markdown]
# ### surface plot

# %%
# creating a 3d space
# Figure, which contains all the plot elements.
fig = plt.figure()
# The gca() method figure module of matplotlib library is used to get the current axes.
axes = fig.gca(projection="3d")
axes.plot_surface(a,b,a**2+b**2,cmap="coolwarm")
plt.show()

# %% [markdown]
# ### contour plot

# %%
# creating a 3d space
# Figure, which contains all the plot elements.
fig = plt.figure()
# The gca() method figure module of matplotlib library is used to get the current axes.
axes = fig.gca(projection="3d")
axes.contour(a,b,a**2+b**2,cmap="coolwarm")
plt.show()

# %% [markdown]
# ##  Try yourself :
# - Download the .py file and run it through cmd
#           Expected output : interactive plot

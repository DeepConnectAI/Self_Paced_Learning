# %% [markdown]
# # Numpy

# %%
import numpy as np

# %%
# array
a = np.array([1,2,3,4,5])
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
# type
print(type(a))
# Out:
# <class 'numpy.ndarray'>

# %%
# shape
a.shape
# Out:
# (5,)

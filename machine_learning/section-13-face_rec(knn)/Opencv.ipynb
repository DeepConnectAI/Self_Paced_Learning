# %% [markdown]
# # OpenCv-basics

# %% [markdown]
# ## Dealing with images

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img_o = cv2.imread("./../data_sets/sample_images/pattinson-batman-screentest.jpg")
img_m = plt.imread("./../data_sets/sample_images/pattinson-batman-screentest.jpg")
img_g = cv2.imread("./../data_sets/sample_images/pattinson-batman-screentest.jpg",cv2.IMREAD_GRAYSCALE)

# %%
# change of color space from bgr to rgb
newImg = cv2.cvtColor(img_o,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_o)
plt.axis("off")
plt.show()

# %%
plt.imshow(img_m)
plt.axis("off")
plt.show()

# %%
plt.imshow(img_g)
plt.axis("off")
plt.show()

# %%
# change in color space is not required using cv2.imshow
cv2.imshow("Batman",img_o) 
cv2.waitKey(0) 
cv2.destroyWindow("Batman")

# %%
# change in color space is not required using cv2.imshow
cv2.imshow("Batman",img_g) 
cv2.waitKey(0) 
cv2.destroyWindow("Batman")

# %%
# change in color space is not required using cv2.imshow
cv2.imshow("Batman",img_m) 
cv2.waitKey(0) 
cv2.destroyWindow("Batman")

# %% [markdown]
# ## Dealing with video

# %%
import cv2
cap = cv2.VideoCapture(0)
while True:
    ret,frame = cap.read()
    
    if ret == False:
        continue
    
    cv2.imshow("Video Frame",frame)
    gray_frame = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    cv2.imshow("Video gray Frame",gray_frame)
    # we get a 32 bit expression & 11111111 -> 8 bit expression which tells us which kye was pressed  
    key_pressed = cv2.waitKey(1) & 0xFF
    if key_pressed == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break
